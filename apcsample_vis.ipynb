# %%
# %matplotlib inline

import pickle
import cv2
from apc_data import APCSample
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # one sample

# %%
sib_sample_path = '/home/leus/ros/indigo' + \
 '/src/start-jsk/jsk_apc/jsk_apc2016_common/debug/data/sib_sample/save_pick_layout_1_2016061013_bin_k'

# %%
with open(sib_sample_path + '.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data.keys()
# Out:
# ['dist2shelf_image',
#  'depth_image',
#  'objects',
#  'height3D_image',
#  'target_object']

# %%
plt.imshow(data['dist2shelf_image'])

# %%
plt.imshow(data['depth_image'])
data['depth_image'][100:120, 300:400]
# Out:
# array([[ 820.,  821.,  821., ...,  822.,  822.,  821.],
#        [ 819.,    0.,  820., ...,  825.,  824.,  823.],
#        [ 819.,    0.,  820., ...,  827.,  826.,  826.],
#        ...,
#        [ 824.,    0.,    0., ...,  830.,  829.,  833.],
#        [ 822.,    0.,    0., ...,  828.,  828.,  827.],
#        [ 820.,  822.,  823., ...,  828.,  828.,  827.]], dtype=float16)

# %%
apc_sample = APCSample(labeled=False, data_2016_prefix=sib_sample_path)
    

def visualize_color_image(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_HSV2RGB))

    
def basic_image_check(img):
    print np.max(img)
    print img.dtype
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-c2fec4176616> in <module>()
# ----> 1 apc_sample = APCSample(labeled=False, data_2016_prefix=sib_sample_path)
#       2
#       3
#       4 def visualize_color_image(img):
#       5     plt.imshow(cv2.cvtColor(img, cv2.COLOR_HSV2RGB))
#
# /home/leus/ros/indigo/src/start-jsk/jsk_apc/jsk_apc2016_common/python/jsk_apc2016_common/rbo_segmentation/apc_data.py in __init__(self, image_filename, apc_sample, labeled, infer_shelf_mask, pickle_mask, image_input, bin_mask_input, data_input, data_dict, data_2016_prefix, is_2016)
#      50
#      51         if data_2016_prefix is not None:
# ---> 52             self.data_dict = self.get_data_from_2016_path(data_2016_prefix)
#      53             self.image = self.data_dict['color']
#      54             self.bin_mask = self.data_dict['mask_image']
#
# /home/leus/ros/indigo/src/start-jsk/jsk_apc/jsk_apc2016_common/python/jsk_apc2016_common/rbo_segmentation/apc_data.py in get_data_from_2016_path(self, path)
#      74             data = pickle.load(f)
#      75
# ---> 76         data['color'] = cv2.cvtColor(cv2.imread(path + '_color.png'), cv2.COLOR_BGR2HSV)
#      77
#      78         data['mask_image'] = np.sum(cv2.imread(path + '_mask.pbm'), axis=2).astype(np.bool)
#
# error: /build/buildd/opencv-2.4.8+dfsg1/modules/imgproc/src/color.cpp:3959: error: (-215) (scn == 3 || scn == 4) && (depth == CV_8U || depth == CV_32F) in function cvtColor

# %%
visualize_color_image(apc_sample.image)

# %%
apc_sample.candidate_objects
# Out:
# ['kyjen_squeakin_eggs_plush_puppies',
#  'barkely_hide_bones',
#  'cloud_b_plush_bear',
#  'shelf']

# %%
apc_sample.feature_images.keys()
dist = apc_sample.feature_images['dist2shelf']
height = apc_sample.feature_images['height3D']
depth = apc_sample.feature_images['depth']

basic_image_check(dist)
basic_image_check(height)
basic_image_check(depth)
# Out:
# 29
# uint8
# 255
# uint8
# 1035.0
# float32

# %%
plt.imshow(apc_sample.feature_images['depth'])

# %%
apc_sample.data_dict.keys()
# Out:
# ['mask_image',
#  'height2D_image',
#  'color',
#  'target_object',
#  'dist2shelf_image',
#  'objects',
#  'has3D_image',
#  'depth_image',
#  'height3D_image']

# %%
dist_dict = apc_sample.data_dict['dist2shelf_image']
height_dict = apc_sample.data_dict['height3D_image']
basic_image_check(dist_dict)
plt.imshow(dist_dict)
# Out:
# 29.0
# float32

# %%
plt.imshow(dist_dict.astype('uint8'))

# %%
basic_image_check(height_dict)
plt.imshow(height_dict)
# Out:
# 111.0
# float32
